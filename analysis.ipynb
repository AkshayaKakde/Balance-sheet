# %%
pip install pandas seaborn matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'Reliance_financial_data.csv'
data = pd.read_csv(file_path)

data = data.drop(columns=['Unnamed: 6'])
data
# Out:
#    Balance Sheet of Reliance Industries(in Rs. Cr.)        Mar 24  \
# 0                                               NaN       12 mths
# 1                          EQUITIES AND LIABILITIES           NaN
# 2                               SHAREHOLDER'S FUNDS           NaN
# 3                              Equity Share Capital      6,766.00
# 4                               Total Share Capital      6,766.00
# 5                              Reserves and Surplus    786,715.00
# 6                        Total Reserves and Surplus    786,715.00
# 7                          Total Shareholders Funds    793,481.00
# 8                                 Minority Interest    132,307.00
# 9                           NON-CURRENT LIABILITIES           NaN
# 10                             Long Term Borrowings    222,712.00
# 11                   Deferred Tax Liabilities [Net]     72,241.00
# 12                      Other Long Term Liabilities    135,834.00
# ...

# %%
# Data Prepocessing

# %%
list(data.columns)
# Out:
# ['Balance Sheet of Reliance Industries(in Rs. Cr.)',
#  'Mar 24',
#  'Mar 23',
#  'Mar 22',
#  'Mar 21',
#  'Mar 20']

# %%
def clean_and_convert(df):

    columns_to_clean = ['Mar 24', 'Mar 23', 'Mar 22', 'Mar 21', 'Mar 20']

    for col in columns_to_clean:

        df[col] = df[col].apply(lambda x: float(str(x).replace(',', '')) if pd.notnull(x) and str(x).replace(',', '').replace('.', '').isdigit() else None)


    df = df.dropna(how='all', subset=columns_to_clean)

    return df

# %%
df = clean_and_convert(data)
df
# Out:
#    Balance Sheet of Reliance Industries(in Rs. Cr.)     Mar 24      Mar 23  \
# 3                              Equity Share Capital     6766.0     6765.00
# 4                               Total Share Capital     6766.0     6765.00
# 5                              Reserves and Surplus   786715.0   709106.00
# 6                        Total Reserves and Surplus   786715.0   709106.00
# 7                          Total Shareholders Funds   793481.0   715871.00
# 8                                 Minority Interest   132307.0   113009.00
# 10                             Long Term Borrowings   222712.0   183176.00
# 11                   Deferred Tax Liabilities [Net]    72241.0    60324.00
# 12                      Other Long Term Liabilities   135834.0   137700.00
# 13                             Long Term Provisions     2044.0     1607.00
# 14                    Total Non-Current Liabilities   432831.0   382807.00
# ...

# %%
list(df["Balance Sheet of Reliance Industries(in Rs. Cr.)"])
# Out:
# ['Equity Share Capital',
#  'Total Share Capital',
#  'Reserves and Surplus',
#  'Total Reserves and Surplus',
#  'Total Shareholders Funds',
#  'Minority Interest',
#  'Long Term Borrowings',
#  'Deferred Tax Liabilities [Net]',
#  'Other Long Term Liabilities',
#  'Long Term Provisions',
#  'Total Non-Current Liabilities',
#  'Short Term Borrowings',
#  'Trade Payables',
#  'Other Current Liabilities',
#  'Short Term Provisions',
#  'Total Current Liabilities',
#  'Total Capital And Liabilities',
#  'Tangible Assets',
#  'Intangible Assets',
#  'Capital Work-In-Progress',
#  'Fixed Assets',
#  'Non-Current Investments',
#  'Deferred Tax Assets [Net]',
#  'Long Term Loans And Advances',
#  'Other Non-Current Assets',
#  'Total Non-Current Assets',
#  'Current Investments',
#  'Inventories',
#  'Trade Receivables',
#  'Cash And Cash Equivalents',
#  'Short Term Loans And Advances',
#  'OtherCurrentAssets',
#  'Total Current Assets',
#  'Total Assets',
#  'Contingent Liabilities',
# ...

# %% [markdown]
# ##**1. Plotted graphs for each catogery:**

# %%
# Converted the data to long format
df_long = df.melt(id_vars=["Balance Sheet of Reliance Industries(in Rs. Cr.)"],
                  var_name="Year",
                  value_name="Value")

# Ploted using Matplotlib
plt.figure(figsize=(14, 10))

# Ploted each category
for category in df_long["Balance Sheet of Reliance Industries(in Rs. Cr.)"].unique():
    subset = df_long[df_long["Balance Sheet of Reliance Industries(in Rs. Cr.)"] == category]
    plt.plot(subset["Year"], subset["Value"], label=category)

plt.title('Balance Sheet Trends of Reliance Industries')
plt.xlabel('Year')
plt.ylabel('Value (in Rs. Cr.)')
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Explaination:**
#
#  The graph shows that **'Equity Share Capital'** has been decreasing steadily over the past four years, while **'Total Share Capital'** has been relatively stable. This suggests that the company has been relying less on issuing new shares and more on other sources of financing, such as debt or retained earnings. The **'Reserves and Surplus'** have also been increasing, indicating that the company is generating profits and reinvesting them back into the business.

# %% [markdown]
# **2. To provide a thorough analysis and advise users on whether investing in Reliance Industries would be fruitful based on balance sheet data and the generated graph, we'll need to consider several financial metrics and trends. Here’s a step-by-step approach to creating a detailed analysis:**

# %% [markdown]
# **1. Key Observations from the Balance Sheet:**
#
# * **Equity Share Capital and Total Share Capital** have remained relatively stable.
# * **Reserves and Surplus** have seen a significant increase over the years, indicating retained earnings and profitability.
# * **Long Term Borrowings** have varied, showing a peak in 2020, a decrease in 2021, and a rise again by 2024.
# * **Total Non-Current Liabilities and Total Current Liabilities** have also fluctuated, showing varying levels of debt.
# * **Fixed Assets** have seen a significant increase, indicating capital investment.
#
# **2. Graphical Analysis:**
#
# From the graph, we can see various balance sheet items' trends. Notably, Reserves and Surplus have shown an upward trend, while some liabilities have shown a decrease or varied trends.
#
# **3. Investment Advice:**
#
#  **Positive Indicators:**
#
# * **Reserves and Surplus Growth:** Consistent growth in reserves and surplus suggests strong profitability and retained earnings.
#
# * **Increase in Fixed Assets:** Indicates potential growth and expansion, which can be positive for long-term growth.
#
# **Caution:**
#
# * **Fluctuating Liabilities:** Both short-term and long-term liabilities have shown fluctuations. This requires a deeper look into the reasons behind the borrowings and whether they are being managed efficiently.
#
# * **Cash and Cash Equivalents:** While there is a substantial amount, it's important to see how it compares with current liabilities.
#
#
# **4. Additional Considerations:**
#
# * **Market Conditions:** Current economic and market conditions can significantly affect the performance of any company.
#
# * **Industry Performance:** The performance of the industry in which Reliance operates should also be considered.
#
# * **Future Plans:** Any announced future projects, investments, or expansions can influence investment decisions.

# %% [markdown]
# ##**Detailed Steps to Implement the Above Analysis in Python:**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data = {
    "Category": ["Equity Share Capital", "Total Share Capital", "Reserves and Surplus", "Total Reserves and Surplus",
                 "Total Shareholders Funds", "Minority Interest", "Long Term Borrowings", "Deferred Tax Liabilities [Net]",
                 "Other Long Term Liabilities", "Long Term Provisions", "Total Non-Current Liabilities", "Short Term Borrowings",
                 "Trade Payables", "Other Current Liabilities", "Short Term Provisions", "Total Current Liabilities",
                 "Total Capital And Liabilities", "Tangible Assets", "Intangible Assets", "Capital Work-In-Progress",
                 "Fixed Assets", "Non-Current Investments", "Deferred Tax Assets [Net]", "Long Term Loans And Advances",
                 "Other Non-Current Assets", "Total Non-Current Assets", "Current Investments", "Inventories",
                 "Trade Receivables", "Cash And Cash Equivalents", "Short Term Loans And Advances", "OtherCurrentAssets",
                 "Total Current Assets", "Total Assets", "Contingent Liabilities", "Bonus Equity Share Capital",
                 "Non-Current Investments Quoted Market Value", "Non-Current Investments Unquoted Book Value",
                 "Current Investments Quoted Market Value", "Current Investments Unquoted Book Value"],
    "Mar 24": [6766, 6766, 786715, 786715, 793481, 132307, 222712, 72241, 135834, 2044, 432831, 101910, 178377, 114905, 2175, 397367, 1755986,
               1103851, 0, 0, 1103851, 119502, 938, 899, 45707, 1285886, 106170, 152770, 31628, 97225, 2517, 79790, 470100, 1755986, 0, 0, 0, 0, 0, 0],
    "Mar 23": [6765, 6765, 709106, 709106, 715871, 113009, 183176, 60324, 137700, 1607, 382807, 130790, 147172, 115604, 2178, 395744, 1607431,
               570503, 139032, 117259, 1003287, 117087, 1549, 1525, 43417, 1182135, 118473, 140008, 28448, 68664, 176, 69527, 425296, 1607431, 73401, 5188.89, 0, 0, 0, 0],
    "Mar 22": [6765, 6765, 772720, 772720, 779485, 109499, 187699, 49644, 62823, 1853, 302019, 78606, 159330, 68790, 1936, 308662, 1499665,
               500454, 114335, 68052, 787295, 286146, 1043, 1588, 63565, 1152646, 108118, 107778, 23640, 36178, 130, 71175, 347019, 1499665, 46454, 5188.89, 0, 0, 0, 0],
    "Mar 21": [6445, 6445, 693727, 693727, 700172, 99260, 163683, 37001, 40903, 2625, 244212, 60081, 108897, 106086, 2504, 277568, 1321212,
               451066, 79980, 71171, 656999, 212382, 1147, 2484, 64977, 948201, 152446, 81672, 19014, 17397, 65, 102417, 373011, 1321212, 85366, 5188.89, 0, 193228, 0, 115098],
    "Mar 20": [6339, 6339, 442827, 442827, 449166, 12181, 197631, 54123, 38108, 1790, 291652, 93786, 96799, 220440, 1890, 412915, 1165915,
               435920, 86479, 59096, 631505, 203852, 2900, 21732, 37407, 907655, 72915, 73903, 19656, 30920, 669, 60197, 258260, 1165915, 54891, 5188.89, 0, 174448, 0, 40993]
}

df = pd.DataFrame(data)

# Plotting the balance sheet trends
plt.figure(figsize=(12, 8))
for column in df.columns[1:]:
    plt.plot(df['Category'], df[column], label=column)

plt.title('Balance Sheet Trends of Reliance Industries')
plt.xlabel('Year')
plt.ylabel('Value (in Rs. Cr.)')
plt.legend(loc='best')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conclusion:**
#
# Based on the data and trends observed, investing in Reliance Industries could be considered favorable due to its strong growth in reserves and fixed assets, indicating profitability and expansion. However, investors should also consider the fluctuating liabilities and current market conditions before making any investment decisions.

# %% [markdown]
# ##**3. Graphical explaination year wise.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data preparation
data = {
    "Year": ["Mar 24", "Mar 23", "Mar 22", "Mar 21", "Mar 20"],
    "Equity Share Capital": [6766.0, 6765.00, 6765.00, 6445.00, 6339.00],
    "Reserves and Surplus": [786715.0, 709106.00, 772720.00, 693727.00, 442827.00],
    "Total Shareholders Funds": [793481.0, 715871.00, 779485.00, 700172.00, 449166.00],
    "Minority Interest": [132307.0, 113009.00, 109499.00, 99260.00, 12181.00],
    "Long Term Borrowings": [222712.0, 183176.00, 187699.00, 163683.00, 197631.00],
    "Deferred Tax Liabilities [Net]": [72241.0, 60324.00, 49644.00, 37001.00, 54123.00],
    "Total Non-Current Liabilities": [432831.0, 382807.00, 302019.00, 244212.00, 291652.00],
    "Total Current Liabilities": [397367.0, 395744.00, 308662.00, 277568.00, 412915.00],
    "Total Capital And Liabilities": [1755986.0, 1607431.00, 1499665.00, 1321212.00, 1165915.00],
    "Total Non-Current Assets": [1285886.0, 1182135.00, 1152646.00, 948201.00, 907655.00],
    "Total Current Assets": [470100.0, 425296.00, 347019.00, 373011.00, 258260.00],
    "Total Assets": [1755986.0, 1607431.00, 1499665.00, 1321212.00, 1165915.00]
}

# Converting the data to a DataFrame
df = pd.DataFrame(data)

# Function to plot bar graphs
def plot_bar_graph(df, column):
    plt.figure(figsize=(10, 6))
    plt.bar(df["Year"], df[column], color='skyblue')
    plt.xlabel('Year')
    plt.ylabel(column)
    plt.title(f'{column} Over Years')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Plotting specific columns
columns_to_plot = [
    "Equity Share Capital",
    "Reserves and Surplus",
    "Total Shareholders Funds",
    "Minority Interest",
    "Long Term Borrowings",
    "Deferred Tax Liabilities [Net]",
    "Total Non-Current Liabilities",
    "Total Current Liabilities",
    "Total Capital And Liabilities",
    "Total Non-Current Assets",
    "Total Current Assets",
    "Total Assets"
]

for column in columns_to_plot:
    plot_bar_graph(df, column)

# %% [markdown]
# ##**Explanation:**
#
# **1. Equity Share Capital**
#
# **Trend:** The equity share capital has shown a gradual increase from Rs. 6339 crore in Mar 20 to Rs. 6766 crore in Mar 24.
#
# **Explanation:** This reflects a stable growth in the company's equity base, possibly due to new equity issuances or internal growth strategies.
#
# **2. Reserves and Surplus**
#
# **Trend:** A significant increase over the years, from Rs. 442827 crore in Mar 20 to Rs. 786715 crore in Mar 24.
#
# **Explanation:** This indicates strong profitability and retained earnings, contributing to the company’s financial health and shareholder value.
#
# **3. Total Shareholders' Funds**
#
# **Trend:** A steady increase from Rs. 449166 crore in Mar 20 to Rs. 793481 crore in Mar 24.
#
# **Explanation:** The rise in shareholders' funds aligns with the growth in reserves and surplus, showcasing overall financial strength and equity growth.
#
# **4. Minority Interest**
#
# **Trend:** Fluctuating but generally increasing from Rs. 12181 crore in Mar 20 to Rs. 132307 crore in Mar 24.
#
# **Explanation:** The rise in minority interest indicates increasing investments in subsidiaries or joint ventures where Reliance does not own 100% equity.
#
# **5. Long Term Borrowings**
#
# **Trend:** Variable trend with a decrease from Rs. 197631 crore in Mar 20 to Rs. 163683 crore in Mar 21, followed by an increase to Rs. 222712 crore in Mar 24.
#
# **Explanation:** The fluctuating borrowings could be due to strategic debt management, refinancing, or capital investment needs.
#
# **6. Deferred Tax Liabilities [Net]**
#
# **Trend:** Increasing trend from Rs. 54123 crore in Mar 20 to Rs. 72241 crore in Mar 24.
#
# **Explanation:** This growth in deferred tax liabilities suggests higher taxable temporary differences, possibly due to changes in tax laws or accounting treatments.
#
# **7. Total Non-Current Liabilities**
#
# **Trend:** A general increase from Rs. 291652 crore in Mar 20 to Rs. 432831 crore in Mar 24.
#
# **Explanation:** The rise indicates greater long-term obligations, possibly due to increased borrowings, deferred taxes, or other long-term financial strategies.
#
# **8. Total Current Liabilities**
#
# **Trend:** Initially decreasing from Rs. 412915 crore in Mar 20 to Rs. 277568 crore in Mar 21, then increasing to Rs. 397367 crore in Mar 24.
#
# **Explanation:** Changes in current liabilities reflect variations in short-term financial obligations, which can fluctuate with business cycles, operational needs, or changes in working capital management.
#
# **9. Total Capital and Liabilities**
#
# **Trend:** Consistent growth from Rs. 1165915 crore in Mar 20 to Rs. 1755986 crore in Mar 24.
#
# **Explanation:** This reflects overall expansion and growth in the company’s balance sheet, indicating increased capital, liabilities, and possibly asset growth.
#
# **10. Total Non-Current Assets**
#
# **Trend:** Significant growth from Rs. 907655 crore in Mar 20 to Rs. 1285886 crore in Mar 24.
#
# **Explanation:** The increase in non-current assets indicates substantial investments in long-term assets like property, plant, equipment, and investments, showing a focus on growth and expansion.
#
# **11. Total Current Assets**
#
# **Trend:** Rising from Rs. 258260 crore in Mar 20 to Rs. 470100 crore in Mar 24.
#
# **Explanation:** This growth in current assets points to increased liquidity, inventory, receivables, and other short-term assets, supporting operational capabilities and working capital.
#
# **12. Total Assets**
#
# **Trend:** A steady increase from Rs. 1165915 crore in Mar 20 to Rs. 1755986 crore in Mar 24.
#
# **Explanation:** The overall rise in total assets reflects the company's growth, expansion strategies, and investments in both current and non-current assets.
#
# ##**Graphical Plots Summary:**
# These trends provide insights into Reliance Industries' financial health, operational efficiency, investment strategies, and growth trajectories. The visualizations can help stakeholders quickly understand the company's financial developments over the years.
